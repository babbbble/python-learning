# %%
def get_city_population(populations,city):
    try:
        return(populations[city])
    except KeyError as e:
        return(f"City {city} not found in population data.")


city_populations = {"New York": 8336817, "Los Angeles": 3979576, "Chicago": 2679044}
city_name = "New York"
print(get_city_population(city_populations,city_name))
# Out:
# 8336817

# %%
import sys
sys.argv
# Out:
# ['/Users/bytedance/Documents/trae_projects/python learning/.venv/lib/python3.9/site-packages/ipykernel_launcher.py',
#  '--f=/Users/bytedance/Library/Jupyter/runtime/kernel-v3a7d450dbe5e7e69fb96e8cf54a1366a61ca6f395.json']
